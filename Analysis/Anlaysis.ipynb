# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
data=pd.read_csv('https://raw.githubusercontent.com/kasadurgaprasad/Wheather-Prediction.March/main/clean%20and%20preprocessing/wheatherml.csv')

# %%
data
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2016-10-31 23:00:00+00:00  Mostly Cloudy        rain         6.205556
# 1      2016-11-01 00:00:00+00:00  Mostly Cloudy        rain         5.827778
# 2      2016-11-01 01:00:00+00:00  Partly Cloudy        rain         5.311111
# 3      2016-11-01 02:00:00+00:00  Partly Cloudy        rain         4.800000
# 4      2016-11-01 03:00:00+00:00          Clear        rain         4.483333
# ...                          ...            ...         ...              ...
# 96448  2016-05-09 17:00:00+00:00  Partly Cloudy        rain        19.972222
# 96449  2016-05-09 18:00:00+00:00  Partly Cloudy        rain        17.816667
# 96450  2016-05-09 19:00:00+00:00  Partly Cloudy        rain        13.938889
# 96451  2016-05-09 20:00:00+00:00  Partly Cloudy        rain        12.733333
# 96452  2016-05-09 21:00:00+00:00  Partly Cloudy        rain        13.038889
#
# ...

# %%
sns.barplot(x=data['month'],y=data['Precip Type'],estimator=len)
# Out:
# <Axes: xlabel='month', ylabel='Precip Type'>

# %%
rain = data[data['Precip Type']=='rain']

# %%
sns.barplot(y=rain['month_name'],x=rain['Temperature (C)'],estimator=len)
# Out:
# <Axes: xlabel='Temperature (C)', ylabel='month_name'>

# %%
sns.barplot(x=data['year'],y=data['Summary'],estimator=len)
# Out:
# <Axes: xlabel='year', ylabel='Summary'>

# %%
sns.barplot(x= 'year',y = 'Summary', data = rain,estimator=len)
# Out:
# <Axes: xlabel='year', ylabel='Summary'>
