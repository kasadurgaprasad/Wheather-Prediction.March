# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
df=pd.read_csv('https://raw.githubusercontent.com/kasadurgaprasad/Wheather-Prediction.March/main/Analysis/Analysis.csv')

# %%
df
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2016-10-31 23:00:00+00:00  Mostly Cloudy        rain         6.205556
# 1      2016-11-01 00:00:00+00:00  Mostly Cloudy        rain         5.827778
# 2      2016-11-01 01:00:00+00:00  Partly Cloudy        rain         5.311111
# 3      2016-11-01 02:00:00+00:00  Partly Cloudy        rain         4.800000
# 4      2016-11-01 03:00:00+00:00          Clear        rain         4.483333
# ...                          ...            ...         ...              ...
# 96448  2016-05-09 17:00:00+00:00  Partly Cloudy        rain        19.972222
# 96449  2016-05-09 18:00:00+00:00  Partly Cloudy        rain        17.816667
# 96450  2016-05-09 19:00:00+00:00  Partly Cloudy        rain        13.938889
# 96451  2016-05-09 20:00:00+00:00  Partly Cloudy        rain        12.733333
# 96452  2016-05-09 21:00:00+00:00  Partly Cloudy        rain        13.038889
#
# ...

# %%
sns.barplot(x=df['month'],y=df['Precip Type'],estimator=len)
# Out:
# <Axes: xlabel='month', ylabel='Precip Type'>

# %%
rain = df[df['Precip Type']=='rain']

# %%
sns.barplot(y=rain['month_name'],x=rain['Temperature (C)'],estimator=len)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_name'
#
# ...
